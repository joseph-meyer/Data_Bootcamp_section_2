# %%
import pandas as pd
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
        'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
        'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
        'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo  = pd.DataFrame(data)
print(weo)
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# the import statement imports the python package - this provides data structures to make working with labeled data easier

# %% [markdown]
# c. the last line has pd prior to the data function because when you want to see the data with the python pandas package otherwise it will just display the data normally

# %%
print(type(data))
print(type(weo))
# Out:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# b. the data is in the form of a dictionary,
# d. but weo - how the data is organized in pandas - is a Pandas data frame

# %%
weo.T.columns
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
len(weo.index)
weo.shape
# Out:
# (7, 4)

# %%
count_row = weo.shape[0]  # gives number of row count
count_col = weo.shape[1]  # gives number of col count
print(count_row)
print(count_col)
# Out:
# 7
# 4

# %% [markdown]
# this means there are 7 rows and 4 columns

# %%
print(weo.dtypes)
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %% [markdown]
# this means that all of the country column values are floating point numbers, this makes sense because they all have decimals and are not whole integers, except for years because this is a complete integer

# %%
print(weo.T.dtypes)
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# dtype: object

# %%
weo['Year']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %% [markdown]
# this just pulls the data out - but it does not put it into a dataframe

# %%
weo[['Year']]
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %% [markdown]
# the double brackets turns it into a dataframe - whereas one bracket would just pull the data out

# %%
weo[[3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-347-9cc0b3a7a031> in <module>()
# ----> 1 weo[[3]] #.column for index method
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ...

# %% [markdown]
# this tells us we cannot access dataframe columns using this, so this has to be an error, if we were trying to export just the column, it would be more helpful to just use .column() for indexing it - we could not extract it this way

# %%
weo.Year = weo.Year.astype(float)
weo
# Out:
#      BRA    JPN    USA    Year
# 0  13.37  33.43  48.30  2008.0
# 1  13.30  31.83  46.91  2009.0
# 2  14.34  33.71  48.31  2010.0
# 3  15.07  34.29  49.72  2011.0
# 4  15.46  35.60  51.41  2012.0
# 5  15.98  36.79  52.94  2013.0
# 6  16.10  37.39  54.60  2014.0

# %%
t = weo.tail(3)
t
# Out:
#      BRA    JPN    USA    Year
# 4  15.46  35.60  51.41  2012.0
# 5  15.98  36.79  52.94  2013.0
# 6  16.10  37.39  54.60  2014.0

# %% [markdown]
# this shows the last three rows of the dataframe weo

# %%
type(t)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# this is still a dataframe - the only thing now is that the dataframe only contains three rows instead of the original 7, but it is made up of all the same contents that originally made it a data frame

# %%
f = weo.head(4)
f
# Out:
#      BRA    JPN    USA    Year
# 0  13.37  33.43  48.30  2008.0
# 1  13.30  31.83  46.91  2009.0
# 2  14.34  33.71  48.31  2010.0
# 3  15.07  34.29  49.72  2011.0

# %%
weo['BRA']
type(weo['BRA'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# the type for BRA in the data frame is a series

# %%
weo['BRA:JPN'] = weo['BRA']/(weo['JPN'])

# %%
weo
# Out:
#      BRA    JPN    USA    Year   BRA:JPN
# 0  13.37  33.43  48.30  2008.0  0.399940
# 1  13.30  31.83  46.91  2009.0  0.417845
# 2  14.34  33.71  48.31  2010.0  0.425393
# 3  15.07  34.29  49.72  2011.0  0.439487
# 4  15.46  35.60  51.41  2012.0  0.434270
# 5  15.98  36.79  52.94  2013.0  0.434357
# 6  16.10  37.39  54.60  2014.0  0.430596

# %%
weo = weo.drop(columns = 'BRA:JPN')
weo
# Out:
#      BRA    JPN    USA    Year
# 0  13.37  33.43  48.30  2008.0
# 1  13.30  31.83  46.91  2009.0
# 2  14.34  33.71  48.31  2010.0
# 3  15.07  34.29  49.72  2011.0
# 4  15.46  35.60  51.41  2012.0
# 5  15.98  36.79  52.94  2013.0
# 6  16.10  37.39  54.60  2014.0

# %%
weo.columns
# Out:
# Index(['BRA', 'JPN', 'USA', 'Year'], dtype='object')

# %%
list(weo.index)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
list(weo.columns)
# Out:
# ['BRA', 'JPN', 'USA', 'Year']

# %%
weo = weo.set_index('Year')
weo
# Out:
#           BRA    JPN    USA
# Year
# 2008.0  13.37  33.43  48.30
# 2009.0  13.30  31.83  46.91
# 2010.0  14.34  33.71  48.31
# 2011.0  15.07  34.29  49.72
# 2012.0  15.46  35.60  51.41
# 2013.0  15.98  36.79  52.94
# 2014.0  16.10  37.39  54.60

# %%
weo.columns = ['Brazil','Japan','United States']
weo
# Out:
#         Brazil  Japan  United States
# Year
# 2008.0   13.37  33.43          48.30
# 2009.0   13.30  31.83          46.91
# 2010.0   14.34  33.71          48.31
# 2011.0   15.07  34.29          49.72
# 2012.0   15.46  35.60          51.41
# 2013.0   15.98  36.79          52.94
# 2014.0   16.10  37.39          54.60

# %%
weo.to_excel('/Users/josephmeyer/Desktop/weo.xlsx')

# %%
weo.describe()
# Out:
#           Brazil      Japan  United States
# count   7.000000   7.000000       7.000000
# mean   14.802857  34.720000      50.312857
# std     1.161704   1.975238       2.783258
# min    13.300000  31.830000      46.910000
# 25%    13.855000  33.570000      48.305000
# 50%    15.070000  34.290000      49.720000
# 75%    15.720000  36.195000      52.175000
# max    16.100000  37.390000      54.600000

# %% [markdown]
# the .describe function will give you the mean for each variable
# means:
# Brazil : 14.802857
# Japan : 34.720000
# United States: 50.312857

# %%
weo.describe().mean()
# Out:
# Brazil           12.126195
# Japan            27.121280
# United States    38.975764
# dtype: float64

# %% [markdown]
# this takes the mean of all columns in the describe function as featured above - it is NOT taking the mean of GDP's like the question asks - so the above .describe is the best way to find the means

# %%
weo['Mean'] = (weo['Brazil']+weo['Japan']+weo['United States'])/3

# %%
weo
# Out:
#         Brazil  Japan  United States       Mean
# Year
# 2008.0   13.37  33.43          48.30  31.700000
# 2009.0   13.30  31.83          46.91  30.680000
# 2010.0   14.34  33.71          48.31  32.120000
# 2011.0   15.07  34.29          49.72  33.026667
# 2012.0   15.46  35.60          51.41  34.156667
# 2013.0   15.98  36.79          52.94  35.236667
# 2014.0   16.10  37.39          54.60  36.030000

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()

weo.plot(ax=ax, 
         color=['green', 'red','blue','yellow'])

# %%
fig,ax = plt.subplots()

weo.plot(ax=ax, 
         color=['green', 'red','blue','yellow'])
ax.set_yscale('log')

# %%
weo['Brazil'].plot(color='Green')

# %%
url = 'https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv'
ep = pd.read_csv(url)

# %%
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# the variables here are the questions that were asked to the people who filled out the survey - in this case 85 people filled out the survey, and each survey had 9 possible questions, and one time stamp on it, the questions asked can all be seen directly below

# %%
print(ep.dtypes)
# Out:
# TimeStamp                                                                                              object
# Why have you enrolled in this course?                                                                  object
# What program are you enrolled in?                                                                      object
# How much programming experience have you had?                                                          object
# How much experience with probability and statistics have you had?                                      object
# What is your expected major or concentration?                                                          object
# What career path most interests you?                                                                   object
# Do you use social media for information purposes?  Check all that apply.                               object
# ...

# %% [markdown]
# the responses are all objects this is because for each question there are multiple answers

# %%
type(ep.dtypes)
# Out:
# pandas.core.series.Series

# %%
print(ep.dtypes)
# Out:
# Time               object
# Course Purpose?    object
# Program?           object
# Programming?       object
# Stat & Prob?       object
# Major              object
# Career             object
# Social Media       object
# Interests          object
# Special Topics     object
# dtype: object

# %% [markdown]
# all of the variables are type objects this is because of how it might have been exported from a csv coming into jupyter notebook

# %%
print(ep.T.dtypes)
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# 14    object
# 15    object
# 16    object
# 17    object
# 18    object
# 19    object
# 20    object
# 21    object
# 22    object
# 23    object
# 24    object
# 25    object
# 26    object
# 27    object
# 28    object
# 29    object
#        ...
# 55    object
# 56    object
# 57    object
# 58    object
# 59    object
# 60    object
# 61    object
# 62    object
# 63    object
# 64    object
# 65    object
# 66    object
# 67    object
# 68    object
# 69    object
# 70    object
# 71    object
# 72    object
# 73    object
# 74    object
# 75    object
# 76    object
# 77    object
# 78    object
# 79    object
# 80    object
# 81    object
# 82    object
# 83    object
# 84    object
# Length: 85, dtype: object

# %%
ep.columns = ['Time','Course Purpose?','Program?','Programming?','Stat & Prob?','Major','Career', 'Social Media','Interests','Special Topics']
ep
# Out:
#                    Time                                    Course Purpose?  \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %%
ep.count()
# Out:
# Time               85
# Course Purpose?    85
# Program?           85
# Programming?       85
# Stat & Prob?       85
# Major              83
# Career             85
# Social Media       83
# Interests          60
# Special Topics     81
# dtype: int64

# %% [markdown]
# this counts the number of responses for each column/question - most columns had everyone respond - but as evidenced not every column did

# %%
ep[list(ep)[1]]
# Out:
# 0                                To help with my career
# 1                                    I heard it was fun
# 2                                    I like a challenge
# 3                                    I heard it was fun
# 4                                    I heard it was fun
# 5                                    I heard it was fun
# 6                                To help with my career
# 7                                To help with my career
# 8                           I lost my mind for a minute
# 9                                    I heard it was fun
# 10                               To help with my career
# 11                               To help with my career
# 12                               To help with my career
# 13                                   I heard it was fun
# 14    I code/build websites in my spare time as a hobby
# 15                               To help with my career
# 16                          I lost my mind for a minute
# ...

# %% [markdown]
# this creates a list of the values only for everyone who took the survey - and only this question, the number 1 signifies that it was the second column as the first column would have been labeled 0

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# i am living in Santiago de Chile                      1
# Recommended by a professor.                           1
# I code/build websites in my spare time as a hobby     1
# I like a challenge                                    1
# Wanted to try something completely different          1
# To finish my major                                    1
# Name: Course Purpose?, dtype: int64

# %% [markdown]
# this sums the answers in the column indicated by 1, which is the second column, and sums the answers based on how many said that response by aggregating all of the same answers

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2
df538 = pd.read_csv(url)

# %%
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df538.shape
# Out:
# (173, 21)

# %% [markdown]
# this dataframe is 173 rows and 21 columns across, in our case 173 people answered this survey, and could have filled in up to 21 pieces of information with their response

# %%
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# the .head function allows us to read only the first lines, the opposite would be tail which allows you to read the last however many lines - as indicated by the number you select into the paranthesis

# %%
cols = [2,5,15,16,17]
df_2 = df538[df538.columns[cols]]
df_2
# Out:
#                                              Major     Women  Median  P25th  \
# 0                            PETROLEUM ENGINEERING     282.0  110000  95000
# 1                   MINING AND MINERAL ENGINEERING      77.0   75000  55000
# 2                        METALLURGICAL ENGINEERING     131.0   73000  50000
# 3        NAVAL ARCHITECTURE AND MARINE ENGINEERING     135.0   70000  43000
# 4                             CHEMICAL ENGINEERING   11021.0   65000  50000
# 5                              NUCLEAR ENGINEERING     373.0   65000  50000
# 6                                ACTUARIAL SCIENCE    1667.0   62000  53000
# 7                       ASTRONOMY AND ASTROPHYSICS     960.0   62000  31500
# 8                           MECHANICAL ENGINEERING   10907.0   60000  48000
# 9                           ELECTRICAL ENGINEERING   16016.0   60000  45000
# 10                            COMPUTER ENGINEERING    8284.0   60000  45000
# ...

# %% [markdown]
# this extracts the major, meaning the major each student is pursuing, women, how many women are pursuing this major, and then presumably the median, P25th percentile, and P75th percentile for salary, so the median salary, 25th percentile, and 75th percentile

# %%
df_2 = df_2.set_index('Major')
df_2
# Out:
#                                                   Women  Median  P25th   P75th
# Major
# PETROLEUM ENGINEERING                             282.0  110000  95000  125000
# MINING AND MINERAL ENGINEERING                     77.0   75000  55000   90000
# METALLURGICAL ENGINEERING                         131.0   73000  50000  105000
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         135.0   70000  43000   80000
# CHEMICAL ENGINEERING                            11021.0   65000  50000   75000
# NUCLEAR ENGINEERING                               373.0   65000  50000  102000
# ACTUARIAL SCIENCE                                1667.0   62000  53000   72000
# ASTRONOMY AND ASTROPHYSICS                        960.0   62000  31500  109000
# MECHANICAL ENGINEERING                          10907.0   60000  48000   70000
# ELECTRICAL ENGINEERING                          16016.0   60000  45000   72000
# COMPUTER ENGINEERING                             8284.0   60000  45000   75000
# ...

# %%
df538 = df538.set_index('Major')
df538
# Out:
#                                                Rank  Major_code     Total  \
# Major
# PETROLEUM ENGINEERING                             1        2419    2339.0
# MINING AND MINERAL ENGINEERING                    2        2416     756.0
# METALLURGICAL ENGINEERING                         3        2415     856.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         4        2417    1258.0
# CHEMICAL ENGINEERING                              5        2405   32260.0
# NUCLEAR ENGINEERING                               6        2418    2573.0
# ACTUARIAL SCIENCE                                 7        6202    3777.0
# ASTRONOMY AND ASTROPHYSICS                        8        5001    1792.0
# MECHANICAL ENGINEERING                            9        2414   91227.0
# ELECTRICAL ENGINEERING                           10        2408   81527.0
# COMPUTER ENGINEERING                             11        2407   41542.0
# AEROSPACE ENGINEERING                            12        2401   15058.0
# ...

# %%
df538.sort_values(by='Total', ascending=False)
# Out:
#                                                     Rank  Major_code  \
# Major
# PSYCHOLOGY                                           146        5200
# BUSINESS MANAGEMENT AND ADMINISTRATION                77        6203
# BIOLOGY                                              124        3600
# GENERAL BUSINESS                                      58        6200
# COMMUNICATIONS                                        94        1901
# NURSING                                               35        6107
# MARKETING AND MARKETING RESEARCH                      78        6206
# ACCOUNTING                                            41        6201
# ENGLISH LANGUAGE AND LITERATURE                      138        3301
# POLITICAL SCIENCE AND GOVERNMENT                      79        5506
# FINANCE                                               36        6207
# ELEMENTARY EDUCATION                                 139        2304
# ...

# %%
df_3 = df538.sort_values(by='Median', ascending=False).head(10)
df_3
# Out:
#                                            Rank  Major_code    Total      Men  \
# Major
# PETROLEUM ENGINEERING                         1        2419   2339.0   2057.0
# MINING AND MINERAL ENGINEERING                2        2416    756.0    679.0
# METALLURGICAL ENGINEERING                     3        2415    856.0    725.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING     4        2417   1258.0   1123.0
# CHEMICAL ENGINEERING                          5        2405  32260.0  21239.0
# NUCLEAR ENGINEERING                           6        2418   2573.0   2200.0
# ACTUARIAL SCIENCE                             7        6202   3777.0   2110.0
# ASTRONOMY AND ASTROPHYSICS                    8        5001   1792.0    832.0
# COMPUTER ENGINEERING                         11        2407  41542.0  33258.0
# MATERIALS SCIENCE                            14        5008   4279.0   2949.0
#
#                                              Women     Major_category  \
# Major
# ...

# %%
df_3['Median'].head(10).plot(color='Green',)

# %%
cols = [14]
df_3 = df538[df538.columns[cols]].head(10)
df_3
# Out:
#                                            Median
# Major
# PETROLEUM ENGINEERING                      110000
# MINING AND MINERAL ENGINEERING              75000
# METALLURGICAL ENGINEERING                   73000
# NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000
# CHEMICAL ENGINEERING                        65000
# NUCLEAR ENGINEERING                         65000
# ACTUARIAL SCIENCE                           62000
# ASTRONOMY AND ASTROPHYSICS                  62000
# MECHANICAL ENGINEERING                      60000
# ELECTRICAL ENGINEERING                      60000

# %%
df_3.plot(kind='barh', title = 'College Majors by Median Salary')

# %%
cols = [15]
df_4 = df538[df538.columns[cols]].head(10)
df_4
# Out:
#                                            P25th
# Major
# PETROLEUM ENGINEERING                      95000
# MINING AND MINERAL ENGINEERING             55000
# METALLURGICAL ENGINEERING                  50000
# NAVAL ARCHITECTURE AND MARINE ENGINEERING  43000
# CHEMICAL ENGINEERING                       50000
# NUCLEAR ENGINEERING                        50000
# ACTUARIAL SCIENCE                          53000
# ASTRONOMY AND ASTROPHYSICS                 31500
# MECHANICAL ENGINEERING                     48000
# ELECTRICAL ENGINEERING                     45000

# %%
df_4.plot(kind='barh', title = 'Majors by P25th Salary')
